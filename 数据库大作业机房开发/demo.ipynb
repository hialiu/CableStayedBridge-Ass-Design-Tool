# %%
import pandas as pd

df = pd.read_excel("bridge.xlsx")

# %%
df
# Out:
#    bridgeID     bridgeName  builtYear                         span  \
# 0     cb001           泖港大桥       1982                    85+200+85
# 1     cb002         上海闵浦二桥       2010                   251+185.25
# 2     cb003       天津塘沽海河大桥       2002                      310+190
# 3     cb004          洞庭湖大桥       2000              130+310+310+130
# 4     cb005        台南高屏溪大桥       2000                      330+180
# 5     cb006     四川泸州泰安长江大桥       2003                      208+335
# 6     cb007         广州黄埔大桥       2008                      322+383
# 7     cb008         武汉长江二桥       1995                  180+400+180
# 8     cb009  润扬长江公路大桥北汊斜拉桥       2004                  176+406+176
# 9     cb010           嘉绍大桥       2013  270+428+428+428+428+428+270
# 10    cb011       四川宜宾长江大桥       2008                  184+460+184
# 11    cb012       重庆长寿长江大桥       2007                  207+460+207
# 12    cb013         荆沙长江大桥       2000                  200+500+200
# ...
